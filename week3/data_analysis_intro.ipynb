# %% [markdown]
# # Importing Pandas

# %%
import pandas as pd

# %% [markdown]
# # Importing Data

# %%
names = ['id', 'title', 'year', 'rating', 'votes', 'length', 'genres']
data = pd.read_csv("imdb_top_10000.txt", sep = "\t", names = names, index_col = 0)

# %% [markdown]
# # Exploring our Data

# %%
data.head()
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
#
#                                      genres
# id
# tt0111161                       Crime|Drama
# tt0110912                    Crime|Thriller
# tt0137523            Drama|Mystery|Thriller
# tt0133093           Action|Adventure|Sci-Fi
# tt1375666  Action|Adventure|Sci-Fi|Thriller

# %%
data.tail()
# Out:
#                                    title  year  rating  votes     length  \
# id
# tt0807721                 Meduzot (2007)  2007     7.0   1357   78 mins.
# tt0339642          Daltry Calhoun (2005)  2005     5.2   1357  100 mins.
# tt0060880  The Quiller Memorandum (1966)  1966     6.5   1356  104 mins.
# tt0152836                    Taal (1999)  1999     6.5   1356  179 mins.
# tt0279977          The Navigators (2001)  2001     6.9   1356   96 mins.
#
#                                genres
# id
# tt0807721                       Drama
# tt0339642  Comedy|Drama|Music|Romance
# tt0060880      Drama|Mystery|Thriller
# tt0152836             Musical|Romance
# tt0279977                Comedy|Drama

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, tt0111161 to tt0279977
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   10000 non-null  object
#  1   year    10000 non-null  int64
#  2   rating  10000 non-null  float64
#  3   votes   10000 non-null  int64
#  4   length  10000 non-null  object
#  5   genres  9999 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 546.9+ KB

# %%
# there is null data in genres column. filling it with 'no genre':

data['genres'].fillna('no genre', inplace = True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, tt0111161 to tt0279977
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   10000 non-null  object
#  1   year    10000 non-null  int64
#  2   rating  10000 non-null  float64
#  3   votes   10000 non-null  int64
#  4   length  10000 non-null  object
#  5   genres  10000 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 546.9+ KB

# %%
data.describe()
# Out:
#                year        rating          votes
# count  10000.000000  10000.000000   10000.000000
# mean    1993.472800      6.386070   16604.012800
# std       14.829924      1.189933   34563.459698
# min     1950.000000      1.500000    1356.000000
# 25%     1986.000000      5.700000    2333.750000
# 50%     1998.000000      6.600000    4980.500000
# 75%     2005.000000      7.200000   15277.750000
# max     2011.000000      9.200000  619479.000000

# %% [markdown]
# # Exporting Data

# %%
data.to_csv('test.csv', header = True, index = True, sep = ',')

# %% [markdown]
# # Sorting Data

# %%
data.sort_values(by = 'rating')
# Out:
#                                            title  year  rating   votes  \
# id
# tt0270846    Superbabies: Baby Geniuses 2 (2004)  2004     1.5   13196
# tt0059464                 Monster a-Go Go (1965)  1965     1.5    3255
# tt0364986                    Ben & Arthur (2002)  2002     1.5    4675
# tt0421051               Daniel the Wizard (2004)  2004     1.5    8271
# tt1309000                      Dream Well (2009)  2009     1.5    2848
# ...                                          ...   ...     ...     ...
# tt0071562          The Godfather: Part II (1974)  1974     9.0  291169
# tt0060196  The Good, the Bad and the Ugly (1966)  1966     9.0  195238
# tt0110912                    Pulp Fiction (1994)  1994     9.0  490065
# tt0068646                   The Godfather (1972)  1972     9.2  474189
# tt0111161        The Shawshank Redemption (1994)  1994     9.2  619479
#
#               length                              genres
# id
# tt0270846   88 mins.                       Comedy|Family
# tt0059464   70 mins.                       Sci-Fi|Horror
# tt0364986   85 mins.                       Drama|Romance
# tt0421051   81 mins.  Comedy|Crime|Family|Fantasy|Horror
# tt1309000   00 mins.                Comedy|Romance|Sport
# ...              ...                                 ...
# tt0071562  200 mins.                         Crime|Drama
# tt0060196  161 mins.                             Western
# tt0110912  154 mins.                      Crime|Thriller
# tt0068646  175 mins.                         Crime|Drama
# tt0111161  142 mins.                         Crime|Drama
#
# [10000 rows x 6 columns]

# %%
data.sort_values(by = 'rating', ascending = False)
# Out:
#                                            title  year  rating   votes  \
# id
# tt0111161        The Shawshank Redemption (1994)  1994     9.2  619479
# tt0068646                   The Godfather (1972)  1972     9.2  474189
# tt0060196  The Good, the Bad and the Ugly (1966)  1966     9.0  195238
# tt0110912                    Pulp Fiction (1994)  1994     9.0  490065
# tt0252487                Outrageous Class (1975)  1975     9.0    9823
# ...                                          ...   ...     ...     ...
# tt0364986                    Ben & Arthur (2002)  2002     1.5    4675
# tt0060753       Night Train to Mundo Fine (1966)  1966     1.5    3542
# tt0421051               Daniel the Wizard (2004)  2004     1.5    8271
# tt0059464                 Monster a-Go Go (1965)  1965     1.5    3255
# tt0060666        Manos: The Hands of Fate (1966)  1966     1.5   20927
#
#               length                              genres
# id
# tt0111161  142 mins.                         Crime|Drama
# tt0068646  175 mins.                         Crime|Drama
# tt0060196  161 mins.                             Western
# tt0110912  154 mins.                      Crime|Thriller
# tt0252487   87 mins.                        Comedy|Drama
# ...              ...                                 ...
# tt0364986   85 mins.                       Drama|Romance
# tt0060753   89 mins.          Action|Adventure|Crime|War
# tt0421051   81 mins.  Comedy|Crime|Family|Fantasy|Horror
# tt0059464   70 mins.                       Sci-Fi|Horror
# tt0060666   74 mins.                              Horror
#
# [10000 rows x 6 columns]

# %% [markdown]
# # Creating Data Frames from Scratch

# %%
sample_data = {
    'tv': [1243,12352,132],
    'radio': [56,452,67],
    'news': [5436,67,3],
    'sales': [3,664,1]
}

# %%
data2 = pd.DataFrame(sample_data)

# %%
data2
# Out:
#       tv  radio  news  sales
# 0   1243     56  5436      3
# 1  12352    452    67    664
# 2    132     67     3      1

# %%
del data2

# %%
try:
    data2
except:
    print('Data has been deleted')
# Out:
# Data has been deleted

# %% [markdown]
# # Selecting Data

# %%
data['title']
# Out:
# id
# tt0111161    The Shawshank Redemption (1994)
# tt0110912                Pulp Fiction (1994)
# tt0137523                  Fight Club (1999)
# tt0133093                  The Matrix (1999)
# tt1375666                   Inception (2010)
#                           ...
# tt0807721                     Meduzot (2007)
# tt0339642              Daltry Calhoun (2005)
# tt0060880      The Quiller Memorandum (1966)
# tt0152836                        Taal (1999)
# tt0279977              The Navigators (2001)
# Name: title, Length: 10000, dtype: object

# %%
data[['title', 'year']]
# Out:
#                                      title  year
# id
# tt0111161  The Shawshank Redemption (1994)  1994
# tt0110912              Pulp Fiction (1994)  1994
# tt0137523                Fight Club (1999)  1999
# tt0133093                The Matrix (1999)  1999
# tt1375666                 Inception (2010)  2010
# ...                                    ...   ...
# tt0807721                   Meduzot (2007)  2007
# tt0339642            Daltry Calhoun (2005)  2005
# tt0060880    The Quiller Memorandum (1966)  1966
# tt0152836                      Taal (1999)  1999
# tt0279977            The Navigators (2001)  2001
#
# [10000 rows x 2 columns]

# %%
data['rating'].mean()
# Out:
# 6.38607

# %%
data['rating'].min()
# Out:
# 1.5

# %%
data['rating'].max()
# Out:
# 9.2

# %%
data['genres'].unique()
# Out:
# array(['Crime|Drama', 'Crime|Thriller', 'Drama|Mystery|Thriller', ...,
#        'Drama|War|Adventure|Romance', 'Western|Sci-Fi|Thriller',
#        'Adventure|Comedy|Drama|War'], dtype=object)

# %%
data['rating'].value_counts()
# Out:
# 6.8    401
# 7.1    401
# 7.2    386
# 6.7    384
# 7.0    382
#       ...
# 1.5      7
# 1.6      6
# 8.9      5
# 9.0      4
# 9.2      2
# Name: rating, Length: 77, dtype: int64

# %%
data['rating'].value_counts().sort_index()
# Out:
# 1.5     7
# 1.6     6
# 1.7    12
# 1.8    12
# 1.9     9
#        ..
# 8.7    13
# 8.8     9
# 8.9     5
# 9.0     4
# 9.2     2
# Name: rating, Length: 77, dtype: int64

# %%
data['rating'].value_counts().sort_index(ascending = False)
# Out:
# 9.2     2
# 9.0     4
# 8.9     5
# 8.8     9
# 8.7    13
#        ..
# 1.9     9
# 1.8    12
# 1.7    12
# 1.6     6
# 1.5     7
# Name: rating, Length: 77, dtype: int64

# %% [markdown]
# # Plotting

# %%
# %matplotlib inline

# %%
data.plot()
# Out:
# <AxesSubplot:xlabel='id'>

# %%
data.plot(kind = 'scatter', x = 'rating', y = 'votes')
# Out:
# <AxesSubplot:xlabel='rating', ylabel='votes'>

# %%
data.plot(kind = 'scatter', x = 'rating', y = 'votes', alpha = 0.2)
# Out:
# <AxesSubplot:xlabel='rating', ylabel='votes'>

# %%
data['rating'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import seaborn as sns

# %%
sns.lmplot(x = 'rating', y = 'votes', data = data)

# %%
sns.pairplot(data = data)

# %% [markdown]
# # Ordinary Least Squares (OLS) Regression

# %%
import statsmodels.api as sm

# %%
results = sm.OLS(data['votes'], data['rating']).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  votes   R-squared (uncentered):                   0.221
# Model:                            OLS   Adj. R-squared (uncentered):              0.220
# Method:                 Least Squares   F-statistic:                              2829.
# Date:                Fri, 16 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        22:40:18   Log-Likelihood:                     -1.1849e+05
# No. Observations:               10000   AIC:                                  2.370e+05
# Df Residuals:                    9999   BIC:                                  2.370e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# rating      2771.9868     52.115     53.190      0.000    2669.831    2874.143
# ==============================================================================
# Omnibus:                    11448.927   Durbin-Watson:                   0.030
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1297144.076
# Skew:                           5.966   Prob(JB):                         0.00
# Kurtosis:                      57.505   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
data['year'] > 1995
# Out:
# id
# tt0111161    False
# tt0110912    False
# tt0137523     True
# tt0133093     True
# tt1375666     True
#              ...
# tt0807721     True
# tt0339642     True
# tt0060880    False
# tt0152836     True
# tt0279977     True
# Name: year, Length: 10000, dtype: bool

# %%
data[data['year'] > 1995]
# Out:
#                             title  year  rating   votes     length  \
# id
# tt0137523       Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093       The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666        Inception (2010)  2010     8.9  385149  148 mins.
# tt0169547  American Beauty (1999)  1999     8.6  338332  122 mins.
# tt0499549           Avatar (2009)  2009     8.1  336855  162 mins.
# ...                           ...   ...     ...     ...        ...
# tt0118635           Aprile (1998)  1998     6.7    1358   78 mins.
# tt0807721          Meduzot (2007)  2007     7.0    1357   78 mins.
# tt0339642   Daltry Calhoun (2005)  2005     5.2    1357  100 mins.
# tt0152836             Taal (1999)  1999     6.5    1356  179 mins.
# tt0279977   The Navigators (2001)  2001     6.9    1356   96 mins.
#
#                                      genres
# id
# tt0137523            Drama|Mystery|Thriller
# tt0133093           Action|Adventure|Sci-Fi
# tt1375666  Action|Adventure|Sci-Fi|Thriller
# tt0169547                             Drama
# tt0499549   Action|Adventure|Fantasy|Sci-Fi
# ...                                     ...
# tt0118635                            Comedy
# tt0807721                             Drama
# tt0339642        Comedy|Drama|Music|Romance
# tt0152836                   Musical|Romance
# tt0279977                      Comedy|Drama
#
# [5710 rows x 6 columns]

# %%
data[data['year'] > 1966]
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
# ...                                    ...   ...     ...     ...        ...
# tt0118635                    Aprile (1998)  1998     6.7    1358   78 mins.
# tt0807721                   Meduzot (2007)  2007     7.0    1357   78 mins.
# tt0339642            Daltry Calhoun (2005)  2005     5.2    1357  100 mins.
# tt0152836                      Taal (1999)  1999     6.5    1356  179 mins.
# tt0279977            The Navigators (2001)  2001     6.9    1356   96 mins.
#
#                                      genres
# id
# tt0111161                       Crime|Drama
# tt0110912                    Crime|Thriller
# tt0137523            Drama|Mystery|Thriller
# tt0133093           Action|Adventure|Sci-Fi
# tt1375666  Action|Adventure|Sci-Fi|Thriller
# ...                                     ...
# tt0118635                            Comedy
# tt0807721                             Drama
# tt0339642        Comedy|Drama|Music|Romance
# tt0152836                   Musical|Romance
# tt0279977                      Comedy|Drama
#
# [9174 rows x 6 columns]

# %%
data[(data['year'] > 1995) & (data['year'] < 2000)]
# Out:
#                                                 title  year  rating   votes  \
# id
# tt0137523                           Fight Club (1999)  1999     8.8  458173
# tt0133093                           The Matrix (1999)  1999     8.7  448114
# tt0169547                      American Beauty (1999)  1999     8.6  338332
# tt0120338                              Titanic (1997)  1997     7.4  284245
# tt0167404                      The Sixth Sense (1999)  1999     8.2  278210
# ...                                               ...   ...     ...     ...
# tt0117690                    Some Mother's Son (1996)  1996     7.3    1371
# tt0289424                       The Ring Virus (1999)  1999     6.5    1371
# tt0197094  What Becomes of the Broken Hearted? (1999)  1999     6.3    1365
# tt0118635                               Aprile (1998)  1998     6.7    1358
# tt0152836                                 Taal (1999)  1999     6.5    1356
#
#               length                           genres
# id
# tt0137523  139 mins.           Drama|Mystery|Thriller
# tt0133093  136 mins.          Action|Adventure|Sci-Fi
# tt0169547  122 mins.                            Drama
# tt0120338  194 mins.  Adventure|Drama|History|Romance
# tt0167404  107 mins.           Drama|Mystery|Thriller
# ...              ...                              ...
# tt0117690  112 mins.                            Drama
# tt0289424  108 mins.                           Horror
# tt0197094   00 mins.                            Drama
# tt0118635   78 mins.                           Comedy
# tt0152836  179 mins.                  Musical|Romance
#
# [1123 rows x 6 columns]

# %%
data[(data['year'] > 1995) | (data['year'] < 2000)]
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
# ...                                    ...   ...     ...     ...        ...
# tt0807721                   Meduzot (2007)  2007     7.0    1357   78 mins.
# tt0339642            Daltry Calhoun (2005)  2005     5.2    1357  100 mins.
# tt0060880    The Quiller Memorandum (1966)  1966     6.5    1356  104 mins.
# tt0152836                      Taal (1999)  1999     6.5    1356  179 mins.
# tt0279977            The Navigators (2001)  2001     6.9    1356   96 mins.
#
#                                      genres
# id
# tt0111161                       Crime|Drama
# tt0110912                    Crime|Thriller
# tt0137523            Drama|Mystery|Thriller
# tt0133093           Action|Adventure|Sci-Fi
# tt1375666  Action|Adventure|Sci-Fi|Thriller
# ...                                     ...
# tt0807721                             Drama
# tt0339642        Comedy|Drama|Music|Romance
# tt0060880            Drama|Mystery|Thriller
# tt0152836                   Musical|Romance
# tt0279977                      Comedy|Drama
#
# [10000 rows x 6 columns]

# %%
data[(data['year'] > 1995) & (data['year'] < 2000)].sort_values(by = 'rating', ascending = False)
# Out:
#                                               title  year  rating   votes  \
# id
# tt0137523                         Fight Club (1999)  1999     8.8  458173
# tt0133093                         The Matrix (1999)  1999     8.7  448114
# tt0120586                 American History X (1998)  1998     8.6  270082
# tt0169547                    American Beauty (1999)  1999     8.6  338332
# tt0118799                  Life Is Beautiful (1997)  1997     8.5  131578
# ...                                             ...   ...     ...     ...
# tt0118836              Chairman of the Board (1998)  1998     2.1    3352
# tt0117550                 Santa with Muscles (1996)  1996     2.1    6420
# tt0162930                   Die Hard Dracula (1998)  1998     1.9    2306
# tt0120214               Danes Without a Clue (1997)  1997     1.9    1824
# tt0174917  Merlin's Shop of Mystical Wonders (1996)  1996     1.7    2362
#
#               length                    genres
# id
# tt0137523  139 mins.    Drama|Mystery|Thriller
# tt0133093  136 mins.   Action|Adventure|Sci-Fi
# tt0120586  119 mins.               Crime|Drama
# tt0169547  122 mins.                     Drama
# tt0118799  116 mins.  Comedy|Drama|Romance|War
# ...              ...                       ...
# tt0118836   95 mins.                    Comedy
# tt0117550   97 mins.             Family|Comedy
# tt0162930   88 mins.             Comedy|Horror
# tt0120214   79 mins.                    Comedy
# tt0174917   92 mins.            Fantasy|Horror
#
# [1123 rows x 6 columns]

# %% [markdown]
# # Grouping

# %%
data.groupby(data['year'])['rating'].mean()
# Out:
# year
# 1950    7.545161
# 1951    7.478125
# 1952    7.475676
# 1953    7.106383
# 1954    7.371795
#           ...
# 2007    6.303831
# 2008    6.275260
# 2009    6.287290
# 2010    6.340635
# 2011    6.357143
# Name: rating, Length: 62, dtype: float64

# %%
data.groupby(data['year'])['rating'].max()
# Out:
# year
# 1950    8.7
# 1951    8.3
# 1952    8.4
# 1953    8.3
# 1954    8.8
#        ...
# 2007    8.3
# 2008    8.9
# 2009    8.4
# 2010    8.9
# 2011    8.6
# Name: rating, Length: 62, dtype: float64

# %%
data.groupby(data['year'])['rating'].min()
# Out:
# year
# 1950    6.3
# 1951    6.2
# 1952    6.3
# 1953    2.9
# 1954    6.1
#        ...
# 2007    1.6
# 2008    1.7
# 2009    1.5
# 2010    2.2
# 2011    2.1
# Name: rating, Length: 62, dtype: float64

# %% [markdown]
# # Challenges

# %% [markdown]
# 1. what was the highest scoring movie in 1996?
# 2. in what year was the highest rated movie of all time made?
# 3. what five movies has the most votes ever?
# 4. what year in the 1960s had the highest average movie rating

# %% [markdown]
# ## Challenge No 1
# what was the highest scoring movie in 1996

# %%
data[data['year'] == 1996].sort_values(by ='rating', ascending = False).head()
# Out:
#                            title  year  rating   votes     length  \
# id
# tt0116282           Fargo (1996)  1996     8.3  187498   98 mins.
# tt0116231      The Bandit (1996)  1996     8.3   13288  121 mins.
# tt0117951   Trainspotting (1996)  1996     8.2  175993   94 mins.
# tt0117666     Sling Blade (1996)  1996     8.0   44316  135 mins.
# tt0117589  Secrets & Lies (1996)  1996     8.0   15435  142 mins.
#
#                                         genres
# id
# tt0116282                 Crime|Drama|Thriller
# tt0116231  Action|Crime|Drama|Romance|Thriller
# tt0117951                          Crime|Drama
# tt0117666                                Drama
# tt0117589                         Comedy|Drama

# %%
highest_rated_1996_movie = data[data['year'] == 1996].sort_values(by ='rating', ascending = False)[['title', 'rating']].head(2)
highest_rated_1996_movie
# Out:
#                        title  rating
# id
# tt0116282       Fargo (1996)     8.3
# tt0116231  The Bandit (1996)     8.3

# %%
highest_rated_1996_movie['title']
# Out:
# id
# tt0116282         Fargo (1996)
# tt0116231    The Bandit (1996)
# Name: title, dtype: object

# %% [markdown]
# ### Alternative Solution

# %%
data_1996 = data[data['year'] == 1996]
data_1996
# Out:
#                                         title  year  rating   votes  \
# id
# tt0116282                        Fargo (1996)  1996     8.3  187498
# tt0117951                Trainspotting (1996)  1996     8.2  175993
# tt0116629             Independence Day (1996)  1996     6.6  171067
# tt0117500                     The Rock (1996)  1996     7.3  120384
# tt0117571                       Scream (1996)  1996     7.2  106216
# ...                                       ...   ...     ...     ...
# tt0117238                   Omega Doom (1996)  1996     3.8    1479
# tt0118172      The Wind in the Willows (1996)  1996     6.1    1487
# tt0116931  Love and Other Catastrophes (1996)  1996     5.9    1415
# tt0184041                            X (1996)  1996     5.9    1384
# tt0117690            Some Mother's Son (1996)  1996     7.3    1371
#
#               length                                    genres
# id
# tt0116282   98 mins.                      Crime|Drama|Thriller
# tt0117951   94 mins.                               Crime|Drama
# tt0116629  145 mins.          Action|Adventure|Sci-Fi|Thriller
# tt0117500  136 mins.                           Action|Thriller
# tt0117571  103 mins.             Crime|Horror|Mystery|Thriller
# ...              ...                                       ...
# tt0117238   00 mins.                                    Sci-Fi
# tt0118172   88 mins.          Adventure|Family|Fantasy|Musical
# tt0116931   76 mins.                            Comedy|Romance
# tt0184041   97 mins.  Animation|Action|Fantasy|Horror|Thriller
# tt0117690  112 mins.                                     Drama
#
# [265 rows x 6 columns]

# %%
data_1996[data_1996['rating'] == data_1996['rating'].max()]
# Out:
#                        title  year  rating   votes     length  \
# id
# tt0116282       Fargo (1996)  1996     8.3  187498   98 mins.
# tt0116231  The Bandit (1996)  1996     8.3   13288  121 mins.
#
#                                         genres
# id
# tt0116282                 Crime|Drama|Thriller
# tt0116231  Action|Crime|Drama|Romance|Thriller

# %% [markdown]
# ## Challenge No 2
# in what year was the highest rated movie of all time made?

# %%
data.sort_values(by = 'rating', ascending = False).head()
# Out:
#                                            title  year  rating   votes  \
# id
# tt0111161        The Shawshank Redemption (1994)  1994     9.2  619479
# tt0068646                   The Godfather (1972)  1972     9.2  474189
# tt0060196  The Good, the Bad and the Ugly (1966)  1966     9.0  195238
# tt0110912                    Pulp Fiction (1994)  1994     9.0  490065
# tt0252487                Outrageous Class (1975)  1975     9.0    9823
#
#               length          genres
# id
# tt0111161  142 mins.     Crime|Drama
# tt0068646  175 mins.     Crime|Drama
# tt0060196  161 mins.         Western
# tt0110912  154 mins.  Crime|Thriller
# tt0252487   87 mins.    Comedy|Drama

# %%
highest_rated_movie = data.sort_values(by = 'rating', ascending = False).head(2)[['title', 'year', 'rating']]
highest_rated_movie
# Out:
#                                      title  year  rating
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2
# tt0068646             The Godfather (1972)  1972     9.2

# %%
highest_rated_movie['year']
# Out:
# id
# tt0111161    1994
# tt0068646    1972
# Name: year, dtype: int64

# %% [markdown]
# ### Alternative Solution

# %%
data[data['rating'] == data['rating'].max()]
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0068646             The Godfather (1972)  1972     9.2  474189  175 mins.
#
#                 genres
# id
# tt0111161  Crime|Drama
# tt0068646  Crime|Drama

# %% [markdown]
# ## Challenge No 3
# what five movies has the most votes ever?

# %%
five_most_votes_movies = data.sort_values(by = 'votes', ascending = False).head()
five_most_votes_movies
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0468569           The Dark Knight (2008)  2008     8.9  555122  152 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0068646             The Godfather (1972)  1972     9.2  474189  175 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
#
#                                 genres
# id
# tt0111161                  Crime|Drama
# tt0468569  Action|Crime|Drama|Thriller
# tt0110912               Crime|Thriller
# tt0068646                  Crime|Drama
# tt0137523       Drama|Mystery|Thriller

# %%
five_most_votes_movies['title']
# Out:
# id
# tt0111161    The Shawshank Redemption (1994)
# tt0468569             The Dark Knight (2008)
# tt0110912                Pulp Fiction (1994)
# tt0068646               The Godfather (1972)
# tt0137523                  Fight Club (1999)
# Name: title, dtype: object

# %% [markdown]
# ## Challenge No 4
# what year in the 1960s had the highest average movie rating

# %%
average_1960s_rating = data[(data['year'] >= 1960) & (data['year'] < 1970)].groupby('year').mean()
average_1960s_rating
# Out:
#         rating         votes
# year
# 1960  7.247917  10692.104167
# 1961  7.195349   7551.651163
# 1962  7.349057  10355.943396
# 1963  7.103922   8699.352941
# 1964  6.865217   8543.318841
# 1965  6.996875   5933.921875
# 1966  6.895652   7826.028986
# 1967  7.169091   8904.909091
# 1968  6.967213  12314.229508
# 1969  7.011321   7267.150943

# %%
highest_average_1960s_rating = average_1960s_rating.sort_values(by = 'rating', ascending = False).head(1)
highest_average_1960s_rating
# Out:
#         rating         votes
# year
# 1962  7.349057  10355.943396

# %% [markdown]
# # Cleaning Data
# Encountered problem:
# 1. the year on the title is redundant
# 2. the length type should be 'int' not 'object'
# 3. the genres should be separated

# %%
data.head()
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
#
#                                      genres
# id
# tt0111161                       Crime|Drama
# tt0110912                    Crime|Thriller
# tt0137523            Drama|Mystery|Thriller
# tt0133093           Action|Adventure|Sci-Fi
# tt1375666  Action|Adventure|Sci-Fi|Thriller

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, tt0111161 to tt0279977
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   10000 non-null  object
#  1   year    10000 non-null  int64
#  2   rating  10000 non-null  float64
#  3   votes   10000 non-null  int64
#  4   length  10000 non-null  object
#  5   genres  10000 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 866.9+ KB

# %% [markdown]
# ## Formatting Title

# %% [markdown]
# ### Solution 1

# %%
data['formatted title'] = data['title'].str[:-7]
data.head()
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
#
#                                      genres           formatted title
# id
# tt0111161                       Crime|Drama  The Shawshank Redemption
# tt0110912                    Crime|Thriller              Pulp Fiction
# tt0137523            Drama|Mystery|Thriller                Fight Club
# tt0133093           Action|Adventure|Sci-Fi                The Matrix
# tt1375666  Action|Adventure|Sci-Fi|Thriller                 Inception

# %% [markdown]
# ### Solution 2

# %%
data['formatted title'] = data['title'].str.split(' \(').str[0]
data.head()
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
#
#                                      genres           formatted title
# id
# tt0111161                       Crime|Drama  The Shawshank Redemption
# tt0110912                    Crime|Thriller              Pulp Fiction
# tt0137523            Drama|Mystery|Thriller                Fight Club
# tt0133093           Action|Adventure|Sci-Fi                The Matrix
# tt1375666  Action|Adventure|Sci-Fi|Thriller                 Inception

# %% [markdown]
# ## Formatting Length
# solution 1 and solution 2 above (redundant title problem) can be used on this case as well

# %%
data['formatted length'] = data['length'].str.replace('mins.','').astype('int')
data.head()
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
#
#                                      genres           formatted title  \
# id
# tt0111161                       Crime|Drama  The Shawshank Redemption
# tt0110912                    Crime|Thriller              Pulp Fiction
# tt0137523            Drama|Mystery|Thriller                Fight Club
# tt0133093           Action|Adventure|Sci-Fi                The Matrix
# tt1375666  Action|Adventure|Sci-Fi|Thriller                 Inception
#
#            formatted length
# id
# tt0111161               142
# tt0110912               154
# tt0137523               139
# tt0133093               136
# tt1375666               148

# %%
sns.pairplot(data)

# %% [markdown]
# #### It seems that there are some movie that has 0 length value, also 0 votes value

# %%
data[data['formatted length'] == 0].head()
# Out:
#                                                title  year  rating   votes  \
# id
# tt0457430                     Pan's Labyrinth (2006)  2006     8.4  186080
# tt0081505                         The Shining (1980)  1980     8.5  212988
# tt1077258                       Planet Terror (2007)  2007     7.5   74950
# tt0075860  Close Encounters of the Third Kind (1977)  1977     7.8   65768
# tt0054331                           Spartacus (1960)  1960     8.0   55504
#
#              length                                    genres  \
# id
# tt0457430  00 mins.                     Drama|Fantasy|Mystery
# tt0081505  00 mins.                      Drama|Horror|Mystery
# tt1077258  00 mins.                      Action|Horror|Sci-Fi
# tt0075860  00 mins.                              Drama|Sci-Fi
# tt0054331  00 mins.  Action|Adventure|Biography|Drama|History
#
#                               formatted title  formatted length
# id
# tt0457430                     Pan's Labyrinth                 0
# tt0081505                         The Shining                 0
# tt1077258                       Planet Terror                 0
# tt0075860  Close Encounters of the Third Kind                 0
# tt0054331                           Spartacus                 0

# %%
data[data['votes'] == 0].head()
# Out:
# Empty DataFrame
# Columns: [title, year, rating, votes, length, genres, formatted title, formatted length]
# Index: []

# %% [markdown]
# #### Apparently the 0 votes movie is non-existent, probably the votes are so low that they seem to be placed on 0 votes

# %%
data['votes'].min()
# Out:
# 1356

# %%
data['votes'].max()
# Out:
# 619479

# %% [markdown]
# ## Formatting Genres

# %%
multiple_genres = data['genres'].unique()
multiple_genres
# Out:
# array(['Crime|Drama', 'Crime|Thriller', 'Drama|Mystery|Thriller', ...,
#        'Drama|War|Adventure|Romance', 'Western|Sci-Fi|Thriller',
#        'Adventure|Comedy|Drama|War'], dtype=object)

# %%
unique_genres = []
for genres in multiple_genres:
    genres = str(genres).split('|')
    for genre in genres:
        if genre not in unique_genres:
#            print(genre, type(genre), genre not in unique_genres)
            unique_genres.append(genre)

# removing 'no genre' genre from before
unique_genres.remove('no genre')
print(unique_genres)
# Out:
# ['Crime', 'Drama', 'Thriller', 'Mystery', 'Action', 'Adventure', 'Sci-Fi', 'Comedy', 'Romance', 'Fantasy', 'Biography', 'History', 'War', 'Family', 'Animation', 'Musical', 'Horror', 'Western', 'Sport', 'Music', 'Film-Noir', 'Adult', 'News', 'Reality-TV']

# %%
# creating new data variable for genres and title and year

data_genres = data[['formatted title', 'year']].rename(columns = {'formatted title': 'title'})
data_genres
# Out:
#                               title  year
# id
# tt0111161  The Shawshank Redemption  1994
# tt0110912              Pulp Fiction  1994
# tt0137523                Fight Club  1999
# tt0133093                The Matrix  1999
# tt1375666                 Inception  2010
# ...                             ...   ...
# tt0807721                   Meduzot  2007
# tt0339642            Daltry Calhoun  2005
# tt0060880    The Quiller Memorandum  1966
# tt0152836                      Taal  1999
# tt0279977            The Navigators  2001
#
# [10000 rows x 2 columns]

# %%
for genre in unique_genres:
    data_genres[genre] = data['genres'].str.contains(genre).astype('int')
data_genres.head()
# Out:
#                               title  year  Crime  Drama  Thriller  Mystery  \
# id
# tt0111161  The Shawshank Redemption  1994      1      1         0        0
# tt0110912              Pulp Fiction  1994      1      0         1        0
# tt0137523                Fight Club  1999      0      1         1        1
# tt0133093                The Matrix  1999      0      0         0        0
# tt1375666                 Inception  2010      0      0         1        0
#
#            Action  Adventure  Sci-Fi  Comedy  ...  Animation  Musical  Horror  \
# id                                            ...
# tt0111161       0          0       0       0  ...          0        0       0
# tt0110912       0          0       0       0  ...          0        0       0
# tt0137523       0          0       0       0  ...          0        0       0
# tt0133093       1          1       1       0  ...          0        0       0
# tt1375666       1          1       1       0  ...          0        0       0
#
#            Western  Sport  Music  Film-Noir  Adult  News  Reality-TV
# id
# tt0111161        0      0      0          0      0     0           0
# tt0110912        0      0      0          0      0     0           0
# tt0137523        0      0      0          0      0     0           0
# tt0133093        0      0      0          0      0     0           0
# tt1375666        0      0      0          0      0     0           0
#
# [5 rows x 26 columns]

# %%
data_genres['total genre type'] = 0

for genre in unique_genres:
    data_genres['total genre type'] += data_genres[genre]

data_genres.head()
# Out:
#                               title  year  Crime  Drama  Thriller  Mystery  \
# id
# tt0111161  The Shawshank Redemption  1994      1      1         0        0
# tt0110912              Pulp Fiction  1994      1      0         1        0
# tt0137523                Fight Club  1999      0      1         1        1
# tt0133093                The Matrix  1999      0      0         0        0
# tt1375666                 Inception  2010      0      0         1        0
#
#            Action  Adventure  Sci-Fi  Comedy  ...  Musical  Horror  Western  \
# id                                            ...
# tt0111161       0          0       0       0  ...        0       0        0
# tt0110912       0          0       0       0  ...        0       0        0
# tt0137523       0          0       0       0  ...        0       0        0
# tt0133093       1          1       1       0  ...        0       0        0
# tt1375666       1          1       1       0  ...        0       0        0
#
#            Sport  Music  Film-Noir  Adult  News  Reality-TV  total genre type
# id
# tt0111161      0      0          0      0     0           0                 2
# tt0110912      0      0          0      0     0           0                 2
# tt0137523      0      0          0      0     0           0                 3
# tt0133093      0      0          0      0     0           0                 3
# tt1375666      0      0          0      0     0           0                 4
#
# [5 rows x 27 columns]

# %%
data[data_genres['total genre type'] == 0]
# Out:
#                       title  year  rating  votes    length    genres  \
# id
# tt0990404  Chop Shop (2007)  2007     7.2   2104  84 mins.  no genre
#
#           formatted title  formatted length
# id
# tt0990404       Chop Shop                84

# %%
data_genres['total genre type'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data_genres.groupby(data_genres['total genre type']).size()
# Out:
# total genre type
# 0       1
# 1    1396
# 2    3010
# 3    3044
# 4    1759
# 5     600
# 6     139
# 7      42
# 8       8
# 9       1
# dtype: int64

# %% [markdown]
# # Finishing Up

# %%
data.head()
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
#
#                                      genres           formatted title  \
# id
# tt0111161                       Crime|Drama  The Shawshank Redemption
# tt0110912                    Crime|Thriller              Pulp Fiction
# tt0137523            Drama|Mystery|Thriller                Fight Club
# tt0133093           Action|Adventure|Sci-Fi                The Matrix
# tt1375666  Action|Adventure|Sci-Fi|Thriller                 Inception
#
#            formatted length
# id
# tt0111161               142
# tt0110912               154
# tt0137523               139
# tt0133093               136
# tt1375666               148

# %%
data_genres.head()
# Out:
#                               title  year  Crime  Drama  Thriller  Mystery  \
# id
# tt0111161  The Shawshank Redemption  1994      1      1         0        0
# tt0110912              Pulp Fiction  1994      1      0         1        0
# tt0137523                Fight Club  1999      0      1         1        1
# tt0133093                The Matrix  1999      0      0         0        0
# tt1375666                 Inception  2010      0      0         1        0
#
#            Action  Adventure  Sci-Fi  Comedy  ...  Musical  Horror  Western  \
# id                                            ...
# tt0111161       0          0       0       0  ...        0       0        0
# tt0110912       0          0       0       0  ...        0       0        0
# tt0137523       0          0       0       0  ...        0       0        0
# tt0133093       1          1       1       0  ...        0       0        0
# tt1375666       1          1       1       0  ...        0       0        0
#
#            Sport  Music  Film-Noir  Adult  News  Reality-TV  total genre type
# id
# tt0111161      0      0          0      0     0           0                 2
# tt0110912      0      0          0      0     0           0                 2
# tt0137523      0      0          0      0     0           0                 3
# tt0133093      0      0          0      0     0           0                 3
# tt1375666      0      0          0      0     0           0                 4
#
# [5 rows x 27 columns]

# %%
data_temp_1 = data
data_temp_1.head()
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
#
#                                      genres           formatted title  \
# id
# tt0111161                       Crime|Drama  The Shawshank Redemption
# tt0110912                    Crime|Thriller              Pulp Fiction
# tt0137523            Drama|Mystery|Thriller                Fight Club
# tt0133093           Action|Adventure|Sci-Fi                The Matrix
# tt1375666  Action|Adventure|Sci-Fi|Thriller                 Inception
#
#            formatted length
# id
# tt0111161               142
# tt0110912               154
# tt0137523               139
# tt0133093               136
# tt1375666               148

# %%
data_temp_1['title'] = data_temp_1['formatted title']
data_temp_1['length (mins)'] = data_temp_1['formatted length']
data_temp_1 = data_temp_1.drop(['length', 'genres', 'formatted length', 'formatted title'], axis = 1)
data_temp_1.head()
# Out:
#                               title  year  rating   votes  length (mins)
# id
# tt0111161  The Shawshank Redemption  1994     9.2  619479            142
# tt0110912              Pulp Fiction  1994     9.0  490065            154
# tt0137523                Fight Club  1999     8.8  458173            139
# tt0133093                The Matrix  1999     8.7  448114            136
# tt1375666                 Inception  2010     8.9  385149            148

# %%
data_temp_2 = data_genres.drop(['title', 'year'], axis = 1)
data_temp_2.head()
# Out:
#            Crime  Drama  Thriller  Mystery  Action  Adventure  Sci-Fi  Comedy  \
# id
# tt0111161      1      1         0        0       0          0       0       0
# tt0110912      1      0         1        0       0          0       0       0
# tt0137523      0      1         1        1       0          0       0       0
# tt0133093      0      0         0        0       1          1       1       0
# tt1375666      0      0         1        0       1          1       1       0
#
#            Romance  Fantasy  ...  Musical  Horror  Western  Sport  Music  \
# id                           ...
# tt0111161        0        0  ...        0       0        0      0      0
# tt0110912        0        0  ...        0       0        0      0      0
# tt0137523        0        0  ...        0       0        0      0      0
# tt0133093        0        0  ...        0       0        0      0      0
# tt1375666        0        0  ...        0       0        0      0      0
#
#            Film-Noir  Adult  News  Reality-TV  total genre type
# id
# tt0111161          0      0     0           0                 2
# tt0110912          0      0     0           0                 2
# tt0137523          0      0     0           0                 3
# tt0133093          0      0     0           0                 3
# tt1375666          0      0     0           0                 4
#
# [5 rows x 25 columns]

# %%
complete_data = data_temp_1.join(data_temp_2)
complete_data.head()
# Out:
#                               title  year  rating   votes  length (mins)  \
# id
# tt0111161  The Shawshank Redemption  1994     9.2  619479            142
# tt0110912              Pulp Fiction  1994     9.0  490065            154
# tt0137523                Fight Club  1999     8.8  458173            139
# tt0133093                The Matrix  1999     8.7  448114            136
# tt1375666                 Inception  2010     8.9  385149            148
#
#            Crime  Drama  Thriller  Mystery  Action  ...  Musical  Horror  \
# id                                                  ...
# tt0111161      1      1         0        0       0  ...        0       0
# tt0110912      1      0         1        0       0  ...        0       0
# tt0137523      0      1         1        1       0  ...        0       0
# tt0133093      0      0         0        0       1  ...        0       0
# tt1375666      0      0         1        0       1  ...        0       0
#
#            Western  Sport  Music  Film-Noir  Adult  News  Reality-TV  \
# id
# tt0111161        0      0      0          0      0     0           0
# tt0110912        0      0      0          0      0     0           0
# tt0137523        0      0      0          0      0     0           0
# tt0133093        0      0      0          0      0     0           0
# tt1375666        0      0      0          0      0     0           0
#
#            total genre type
# id
# tt0111161                 2
# tt0110912                 2
# tt0137523                 3
# tt0133093                 3
# tt1375666                 4
#
# [5 rows x 30 columns]

# %%
complete_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, tt0111161 to tt0279977
# Data columns (total 30 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             10000 non-null  object
#  1   year              10000 non-null  int64
#  2   rating            10000 non-null  float64
#  3   votes             10000 non-null  int64
#  4   length (mins)     10000 non-null  int64
#  5   Crime             10000 non-null  int64
#  6   Drama             10000 non-null  int64
#  7   Thriller          10000 non-null  int64
#  8   Mystery           10000 non-null  int64
#  9   Action            10000 non-null  int64
#  10  Adventure         10000 non-null  int64
#  11  Sci-Fi            10000 non-null  int64
#  12  Comedy            10000 non-null  int64
#  13  Romance           10000 non-null  int64
#  14  Fantasy           10000 non-null  int64
#  15  Biography         10000 non-null  int64
#  16  History           10000 non-null  int64
#  17  War               10000 non-null  int64
#  18  Family            10000 non-null  int64
#  19  Animation         10000 non-null  int64
#  20  Musical           10000 non-null  int64
#  21  Horror            10000 non-null  int64
#  22  Western           10000 non-null  int64
#  23  Sport             10000 non-null  int64
#  24  Music             10000 non-null  int64
#  25  Film-Noir         10000 non-null  int64
#  26  Adult             10000 non-null  int64
#  27  News              10000 non-null  int64
#  28  Reality-TV        10000 non-null  int64
#  29  total genre type  10000 non-null  int64
# dtypes: float64(1), int64(28), object(1)
# memory usage: 2.7+ MB

# %%
complete_data.describe()
# Out:
#                year        rating          votes  length (mins)        Crime  \
# count  10000.000000  10000.000000   10000.000000   10000.000000  10000.00000
# mean    1993.472800      6.386070   16604.012800     103.578400      0.18670
# std       14.829924      1.189933   34563.459698      26.628698      0.38969
# min     1950.000000      1.500000    1356.000000       0.000000      0.00000
# 25%     1986.000000      5.700000    2333.750000      93.000000      0.00000
# 50%     1998.000000      6.600000    4980.500000     102.000000      0.00000
# 75%     2005.000000      7.200000   15277.750000     115.000000      0.00000
# max     2011.000000      9.200000  619479.000000     450.000000      1.00000
#
#               Drama      Thriller       Mystery        Action     Adventure  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.569700      0.283200      0.100900      0.189100      0.131300
# std        0.495143      0.450575      0.301211      0.391608      0.337745
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        1.000000      0.000000      0.000000      0.000000      0.000000
# 75%        1.000000      1.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        ...       Musical        Horror       Western         Sport  \
# count  ...  10000.000000  10000.000000  10000.000000  10000.000000
# mean   ...      0.026000      0.121500      0.023500      0.028800
# std    ...      0.159143      0.326724      0.151493      0.167252
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...      0.000000      0.000000      0.000000      0.000000
# 50%    ...      0.000000      0.000000      0.000000      0.000000
# 75%    ...      0.000000      0.000000      0.000000      0.000000
# max    ...      1.000000      1.000000      1.000000      1.000000
#
#               Music     Film-Noir         Adult        News  Reality-TV  \
# count  10000.000000  10000.000000  10000.000000  10000.0000  10000.0000
# mean       0.061900      0.004000      0.000900      0.0001      0.0001
# std        0.240986      0.063122      0.029988      0.0100      0.0100
# min        0.000000      0.000000      0.000000      0.0000      0.0000
# 25%        0.000000      0.000000      0.000000      0.0000      0.0000
# 50%        0.000000      0.000000      0.000000      0.0000      0.0000
# 75%        0.000000      0.000000      0.000000      0.0000      0.0000
# max        1.000000      1.000000      1.000000      1.0000      1.0000
#
#        total genre type
# count      10000.000000
# mean           2.778500
# std            1.201325
# min            0.000000
# 25%            2.000000
# 50%            3.000000
# 75%            4.000000
# max            9.000000
#
# [8 rows x 29 columns]

# %%
complete_data.to_csv('test_of_complete_processed_data.csv', header = True, index = True, sep = ',')
